# %%
from langchain_core.messages import HumanMessage, AIMessage
from models import State, Terms
from understanding import ProblemUnderstanding
import yaml

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    #model = "mistral-small:22b-instruct-2409-q6_K",
    model = "qwen2.5:32b-instruct-q6_K",
    #model = "qwen2.5:32b-instruct-q6_K",
    temperature = 0,
    num_ctx=8192,
    num_predict = 3072,
)

# %%
def human_feedback(terms: Terms) -> Terms:
    updated_terms = terms.copy()
    term_definitions = dict()
    for term in terms["doubts"]:
        if not (term in updated_terms["term_definitions"]):
            definition = input(f"TERM '{term}': ")
            term_definitions[term] = definition
    
    return {"term_definitions": term_definitions}

# %%
#human_feedback(Terms(term_definitions={}, doubts=["what's up?"]))
# {'term_definitions': {"what's up?": 'yo'}}

# %%
# Initialize the ProblemUnderstanding class
problem_understanding = ProblemUnderstanding(llm, human_feedback)

initial_state = State(
    messages=[
        HumanMessage(
          content="""Situation: Three siblings – David, Eve, and Frank – inherit a piece of land from their late father. The land is 90 acres in total. According to the will, each sibling is supposed to receive an equal share of the land's value.

Here’s the breakdown of the land:

The northern 60 acres are fertile and highly suitable for farming but difficult to develop for other purposes.
The southern 30 acres are rocky and unsuitable for farming, but prime for development (e.g., building houses, commercial use).
Although the monetary value per acre of both the northern and southern sections is the same due to potential real estate development, the agricultural value of the northern land is much higher than the southern land.

The will states that "each child is to receive an equal share of the land’s value." The ambiguity arises because it’s unclear whether "value" refers to monetary value or agricultural value.

Question:
How should the land be divided among the three siblings?"""
          )
    ]
)

# Run the understanding process
final_state = problem_understanding.understand_problem(initial_state)

# Print the results
AIMessage(yaml.dump(final_state["understanding"])).pretty_print()
# Out:
# --- #[internal step] Rephrasing the problem...
#
# ================================ System Message ================================
#
# You are tasked with rephrasing problems to ensure a deep understanding before solving them. When presented with a problem, follow these steps:
#
# - Restate the problem in clear and simple terms, breaking down complex language or ideas.
# - Focus on the core elements and conditions of the problem.
# - Ensure that the rephrased version is easy to understand and aligns with the original intent of the problem. Don't express your doubts here, simply rephrase the question.
# - Ask yourself: What is the problem really asking for? What conditions must be met?
# - Reflect on any ambiguities in the problem statement and clarify them in your rephrasing.
# Your goal is to ensure that the problem is fully understood before attempting any solution.
# ================================ Human Message =================================
#
# Situation: Three siblings – David, Eve, and Frank – inherit a piece of land from their late father. The land is 90 acres in total. According to the will, each sibling is supposed to receive an equal share of the land's value.
#
# Here’s the breakdown of the land:
#
# The northern 60 acres are fertile and highly suitable for farming but difficult to develop for other purposes.
# The southern 30 acres are rocky and unsuitable for farming, but prime for development (e.g., building houses, commercial use).
# Although the monetary value per acre of both the northern and southern sections is the same due to potential real estate development, the agricultural value of the northern land is much higher than the southern land.
#
# The will states that "each child is to receive an equal share of the land’s value." The ambiguity arises because it’s unclear whether "value" refers to monetary value or agricultural value.
#
# Question:
# How should the land be divided among the three siblings?
#
# --- #[internal step] Identifying goals...
# ================================ System Message ================================
#
# You are tasked with identifying the goals (each independent goal is considered an item) to guide a problem solver in solving the problem. These goals should clarify what needs to be achieved. When presented with a problem, follow these steps:
#
# - Clearly state the primary objective or outcome that the problem is asking to achieve.
# - Break down any sub-goals or intermediate steps necessary to reach the main goal.
# - Distinguish between what is known (facts, conditions) and what is unknown (what must be solved or determined).
# - Ensure the goals are specific and measurable, and not fundamentally an ambiguity in the question, focusing on what success looks like in the context of the problem.
# - Consider whether there may be multiple possible goals or solutions, and clarify each one if applicable.
# Your objective is to make the goals explicit and clear so that the path toward solving the problem is well-defined.  Your goals must be returned as a list of items in the object.
# ================================== Ai Message ==================================
#
# rephrasal: "The problem involves dividing a 90-acre inherited land equally among three\
#   \ siblings based on the 'value' of the land. The land is split into two sections:\
#   \ 60 acres in the north, suitable for farming but not development, and 30 acres\
#   \ in the south, unsuitable for farming but ideal for development. Both sections\
#   \ have equal monetary value due to potential real estate development, though the\
#   \ northern section has a higher agricultural value. The will specifies an 'equal\
#   \ share of the land\u2019s value,' without clarifying whether this refers to monetary\
#   \ or agricultural value."
# ================================ Human Message =================================
#
# Situation: Three siblings – David, Eve, and Frank – inherit a piece of land from their late father. The land is 90 acres in total. According to the will, each sibling is supposed to receive an equal share of the land's value.
#
# Here’s the breakdown of the land:
#
# The northern 60 acres are fertile and highly suitable for farming but difficult to develop for other purposes.
# The southern 30 acres are rocky and unsuitable for farming, but prime for development (e.g., building houses, commercial use).
# Although the monetary value per acre of both the northern and southern sections is the same due to potential real estate development, the agricultural value of the northern land is much higher than the southern land.
#
# The will states that "each child is to receive an equal share of the land’s value." The ambiguity arises because it’s unclear whether "value" refers to monetary value or agricultural value.
#
# Question:
# How should the land be divided among the three siblings?
#
# --- #[internal step] Listing information...
# ================================ System Message ================================
#
# Your task is to make a detailed list of all the information provided in the problem (each independent detail is considered an item). Do not list the goals themselves in this step! Follow these steps:
#
# - Identify and list all the given data points (numbers, conditions, facts, relationships) explicitly stated in the problem.
# - Note any constraints or limitations that must be followed (e.g., boundaries, rules, assumptions).
# - Organize this information clearly, categorizing relevant data and constraints separately if needed.
# - Avoid interpreting or solving at this stage; focus purely on collecting all the information provided.
# Ensure that no relevant information is missed. Your objective is to create a thorough inventory of all the given information to form a strong foundation for problem-solving.
# ================================== Ai Message ==================================
#
# rephrasal: "The problem involves dividing a 90-acre inherited land equally among three\
#   \ siblings based on the 'value' of the land. The land is split into two sections:\
#   \ 60 acres in the north, suitable for farming but not development, and 30 acres\
#   \ in the south, unsuitable for farming but ideal for development. Both sections\
#   \ have equal monetary value due to potential real estate development, though the\
#   \ northern section has a higher agricultural value. The will specifies an 'equal\
#   \ share of the land\u2019s value,' without clarifying whether this refers to monetary\
#   \ or agricultural value."
# goals:
# - Determine if 'equal share of the land's value' in the will refers to monetary value
#   or agricultural value.
# - If it is determined that 'value' means monetary value, divide the 90 acres equally
#   among the three siblings based on equal monetary worth.
# - If it is determined that 'value' means agricultural value, devise a division plan
#   that ensures each sibling receives an equivalent share of the land's farming potential.
# - Consider if there are alternative solutions where both monetary and agricultural
#   values are taken into account to satisfy the will's intent.
# ================================ Human Message =================================
#
# Situation: Three siblings – David, Eve, and Frank – inherit a piece of land from their late father. The land is 90 acres in total. According to the will, each sibling is supposed to receive an equal share of the land's value.
#
# Here’s the breakdown of the land:
#
# The northern 60 acres are fertile and highly suitable for farming but difficult to develop for other purposes.
# The southern 30 acres are rocky and unsuitable for farming, but prime for development (e.g., building houses, commercial use).
# Although the monetary value per acre of both the northern and southern sections is the same due to potential real estate development, the agricultural value of the northern land is much higher than the southern land.
#
# The will states that "each child is to receive an equal share of the land’s value." The ambiguity arises because it’s unclear whether "value" refers to monetary value or agricultural value.
#
# Question:
# How should the land be divided among the three siblings?
#
# --- #[internal step] Defining terms...
# ================================ System Message ================================
#
# Your task is to carefully examine the problem for any terms or concepts that could have multiple meanings or that may not be immediately clear. Follow these steps:
#
# - Identify any terms or concepts in the problem that could lead to confusion due to multiple possible interpretations or lack of clarity. Each should clarify an aspect of the problem that is important for a goal, and the question should not be equivalent to a goal or the answer.
# - List each ambiguous term or concept without attempting to resolve it yet. Focus only on detecting potential issues with understanding the problem.
# - Ensure that each term or concept identified is sufficiently distinct that the user will not sense repetition in the questions or the same underlying ambiguity.
# Do not proceed to explanations or clarifications at this stage—simply highlight the problematic terms or concepts. Provide the terms as a list in the terms->doubts section.
# ================================== Ai Message ==================================
#
# rephrasal: "The problem involves dividing a 90-acre inherited land equally among three\
#   \ siblings based on the 'value' of the land. The land is split into two sections:\
#   \ 60 acres in the north, suitable for farming but not development, and 30 acres\
#   \ in the south, unsuitable for farming but ideal for development. Both sections\
#   \ have equal monetary value due to potential real estate development, though the\
#   \ northern section has a higher agricultural value. The will specifies an 'equal\
#   \ share of the land\u2019s value,' without clarifying whether this refers to monetary\
#   \ or agricultural value."
# goals:
# - Determine if 'equal share of the land's value' in the will refers to monetary value
#   or agricultural value.
# - If it is determined that 'value' means monetary value, divide the 90 acres equally
#   among the three siblings based on equal monetary worth.
# - If it is determined that 'value' means agricultural value, devise a division plan
#   that ensures each sibling receives an equivalent share of the land's farming potential.
# - Consider if there are alternative solutions where both monetary and agricultural
#   values are taken into account to satisfy the will's intent.
# information:
# - The total inherited land is 90 acres.
# - 60 acres in the north are suitable for farming but not development.
# - 30 acres in the south are unsuitable for farming but ideal for development.
# - Both sections have equal monetary value per acre due to real estate potential.
# - The northern section has a higher agricultural value than the southern section.
# ================================ Human Message =================================
#
# Situation: Three siblings – David, Eve, and Frank – inherit a piece of land from their late father. The land is 90 acres in total. According to the will, each sibling is supposed to receive an equal share of the land's value.
#
# Here’s the breakdown of the land:
#
# The northern 60 acres are fertile and highly suitable for farming but difficult to develop for other purposes.
# The southern 30 acres are rocky and unsuitable for farming, but prime for development (e.g., building houses, commercial use).
# Although the monetary value per acre of both the northern and southern sections is the same due to potential real estate development, the agricultural value of the northern land is much higher than the southern land.
#
# The will states that "each child is to receive an equal share of the land’s value." The ambiguity arises because it’s unclear whether "value" refers to monetary value or agricultural value.
#
# Question:
# How should the land be divided among the three siblings?
# doubts
#  2
# asking user to clarify...
#  doubts:
# - equal share of the land's value
# - value
# term_definitions: {}
#
# remaining doubts
#  0
# verifying we have no new doubts immediately ...
#  doubts: []
# term_definitions:
#   equal share of the land's value: in terms of agricultural value
#   value: agricultural value
#
# asking user to clarify...
#  doubts:
# - equal share of the land's value in terms of both monetary and agricultural considerations
# term_definitions:
#   equal share of the land's value: in terms of agricultural value
#   value: agricultural value
#
# remaining doubts
#  0
# verifying we have no new doubts immediately ...
#  doubts: []
# term_definitions:
#   equal share of the land's value: in terms of agricultural value
#   equal share of the land's value in terms of both monetary and agricultural considerations: only
#     agricultural
#   value: agricultural value
#
# ================================== Ai Message ==================================
#
# goals:
# - Determine if 'equal share of the land's value' in the will refers to monetary value
#   or agricultural value.
# - If it is determined that 'value' means monetary value, divide the 90 acres equally
#   among the three siblings based on equal monetary worth.
# - If it is determined that 'value' means agricultural value, devise a division plan
#   that ensures each sibling receives an equivalent share of the land's farming potential.
# - Consider if there are alternative solutions where both monetary and agricultural
#   values are taken into account to satisfy the will's intent.
# information:
# - The total inherited land is 90 acres.
# - 60 acres in the north are suitable for farming but not development.
# - 30 acres in the south are unsuitable for farming but ideal for development.
# - Both sections have equal monetary value per acre due to real estate potential.
# - The northern section has a higher agricultural value than the southern section.
# rephrasal: "The problem involves dividing a 90-acre inherited land equally among three\
#   \ siblings based on the 'value' of the land. The land is split into two sections:\
#   \ 60 acres in the north, suitable for farming but not development, and 30 acres\
#   \ in the south, unsuitable for farming but ideal for development. Both sections\
#   \ have equal monetary value due to potential real estate development, though the\
#   \ northern section has a higher agricultural value. The will specifies an 'equal\
#   \ share of the land\u2019s value,' without clarifying whether this refers to monetary\
#   \ or agricultural value."
# terms:
#   doubts: []
#   term_definitions:
#     equal share of the land's value: in terms of agricultural value
#     equal share of the land's value in terms of both monetary and agricultural considerations: only
#       agricultural
#     value: agricultural value

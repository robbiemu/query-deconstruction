# %%
from langchain_core.messages import HumanMessage, AIMessage
from understanding import ProblemUnderstanding, State, Terms
import yaml

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    #model = "mistral-small:22b-instruct-2409-q6_K",
    model = "qwen2.5:32b-instruct-q6_K",
    temperature = 0.8,
    num_ctx=8192,
    num_predict = 5120,
)

# %%
def human_feedback(terms: Terms) -> Terms:
    updated_terms = terms.copy()
    term_definitions = dict()
    for term in terms["doubts"]:
        if not (term in updated_terms["term_definitions"]):
            definition = input(f"TERM '{term}': ")
            term_definitions[term] = definition
    
    return {"term_definitions": term_definitions}

# %%
#human_feedback(Terms(term_definitions={}, doubts=["what's up?"]))
# {'term_definitions': {"what's up?": 'yo'}}

# %%
# Initialize the ProblemUnderstanding class
problem_understanding = ProblemUnderstanding(llm, human_feedback)

# Create an initial state
initial_state = State(
    messages=[
        HumanMessage(
          content="""Situation: Three siblings – David, Eve, and Frank – inherit a piece of land from their late father. The land is 90 acres in total. According to the will, each sibling is supposed to receive an equal share of the land's value.

Here’s the breakdown of the land:

The northern 60 acres are fertile and highly suitable for farming but difficult to develop for other purposes.
The southern 30 acres are rocky and unsuitable for farming, but prime for development (e.g., building houses, commercial use).
Although the monetary value per acre of both the northern and southern sections is the same due to potential real estate development, the agricultural value of the northern land is much higher than the southern land.

The will states that "each child is to receive an equal share of the land’s value." The ambiguity arises because it’s unclear whether "value" refers to monetary value or agricultural value.

Question:
How should the land be divided among the three siblings?"""
          )
    ]
)

# Run the understanding process
final_state = problem_understanding.understand_problem(initial_state)

# Print the results
AIMessage(yaml.dump(final_state["understanding"])).pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Rephrasing the problem...
# {}
# ================================== Ai Message ==================================
#
# Identifying goals...
# rephrasal:
#   new: "Three siblings - David, Eve, and Frank - have inherited a 90-acre piece of\
#     \ land from their father. The northern 60 acres are suitable for farming but difficult\
#     \ to develop, while the southern 30 acres are unsuitable for farming but ideal\
#     \ for development. Both sections have equal monetary value per acre due to potential\
#     \ real estate development, though the agricultural value differs significantly\
#     \ between the two sections. According to the will, each sibling should receive\
#     \ an equal share of the land\u2019s value, but it is unclear whether this refers\
#     \ to its monetary or agricultural value. How should the 90 acres be divided among\
#     \ the three siblings to ensure that they each get an equal share based on the\
#     \ intended value?"
# ================================== Ai Message ==================================
#
# Listing information...
# goals:
#   items:
#   - Determine whether the will's 'value' refers to monetary or agricultural value
#   - Calculate the total monetary value of both sections (northern 60 acres and southern
#     30 acres)
#   - Divide the land based on its total monetary value if the will's 'value' is monetary
#   - Calculate the total agricultural value of both sections
#   - Divide the land based on its total agricultural value if the will's 'value' is
#     agricultural
#   - Propose a division plan that considers both monetary and agricultural values,
#     ensuring each sibling receives an equal share in terms of overall value
#   - Evaluate potential trade-offs to accommodate preferences while maintaining fairness
#   - Document the division plan with clear measurements, specifying exact acreage for
#     each section
# rephrasal:
#   new: "Three siblings - David, Eve, and Frank - have inherited a 90-acre piece of\
#     \ land from their father. The northern 60 acres are suitable for farming but difficult\
#     \ to develop, while the southern 30 acres are unsuitable for farming but ideal\
#     \ for development. Both sections have equal monetary value per acre due to potential\
#     \ real estate development, though the agricultural value differs significantly\
#     \ between the two sections. According to the will, each sibling should receive\
#     \ an equal share of the land\u2019s value, but it is unclear whether this refers\
#     \ to its monetary or agricultural value. How should the 90 acres be divided among\
#     \ the three siblings to ensure that they each get an equal share based on the\
#     \ intended value?"
# ================================== Ai Message ==================================
#
# Defining terms...
# goals:
#   items:
#   - Determine whether the will's 'value' refers to monetary or agricultural value
#   - Calculate the total monetary value of both sections (northern 60 acres and southern
#     30 acres)
#   - Divide the land based on its total monetary value if the will's 'value' is monetary
#   - Calculate the total agricultural value of both sections
#   - Divide the land based on its total agricultural value if the will's 'value' is
#     agricultural
#   - Propose a division plan that considers both monetary and agricultural values,
#     ensuring each sibling receives an equal share in terms of overall value
#   - Evaluate potential trade-offs to accommodate preferences while maintaining fairness
#   - Document the division plan with clear measurements, specifying exact acreage for
#     each section
# information:
#   items:
#   - The total land is 90 acres, consisting of a northern section of 60 acres suitable
#     for farming and a southern section of 30 acres ideal for development.
#   - Both sections have equal monetary value per acre due to potential real estate
#     development but significantly different agricultural values.
#   - The will states that each sibling should receive an equal share of the land's
#     value, with ambiguity regarding whether this refers to its monetary or agricultural
#     value.
# rephrasal:
#   new: "Three siblings - David, Eve, and Frank - have inherited a 90-acre piece of\
#     \ land from their father. The northern 60 acres are suitable for farming but difficult\
#     \ to develop, while the southern 30 acres are unsuitable for farming but ideal\
#     \ for development. Both sections have equal monetary value per acre due to potential\
#     \ real estate development, though the agricultural value differs significantly\
#     \ between the two sections. According to the will, each sibling should receive\
#     \ an equal share of the land\u2019s value, but it is unclear whether this refers\
#     \ to its monetary or agricultural value. How should the 90 acres be divided among\
#     \ the three siblings to ensure that they each get an equal share based on the\
#     \ intended value?"
# doubts
#  3
# asking user to clarify...
#  doubts:
# - What does 'equal share of the land's value' mean in terms of division?
# - Is it possible that the will intended a mixed approach, combining both monetary
#   and agricultural values?
# - How should preferences or specific needs of each sibling be considered in the distribution
#   process?
# term_definitions: {}
#
# remaining doubts
#  0
# verifying we have no new doubts immediately ...
#  doubts: []
# term_definitions:
#   How should preferences or specific needs of each sibling be considered in the distribution process?: they
#     should not be considered
#   Is it possible that the will intended a mixed approach, combining both monetary and agricultural values?: 'no'
#   What does 'equal share of the land's value' mean in terms of division?: the agricultural
#     value should be the same
#
# ================================== Ai Message ==================================
#
# goals:
#   items:
#   - Determine whether the will's 'value' refers to monetary or agricultural value
#   - Calculate the total monetary value of both sections (northern 60 acres and southern
#     30 acres)
#   - Divide the land based on its total monetary value if the will's 'value' is monetary
#   - Calculate the total agricultural value of both sections
#   - Divide the land based on its total agricultural value if the will's 'value' is
#     agricultural
#   - Propose a division plan that considers both monetary and agricultural values,
#     ensuring each sibling receives an equal share in terms of overall value
#   - Evaluate potential trade-offs to accommodate preferences while maintaining fairness
#   - Document the division plan with clear measurements, specifying exact acreage for
#     each section
# information:
#   items:
#   - The total land is 90 acres, consisting of a northern section of 60 acres suitable
#     for farming and a southern section of 30 acres ideal for development.
#   - Both sections have equal monetary value per acre due to potential real estate
#     development but significantly different agricultural values.
#   - The will states that each sibling should receive an equal share of the land's
#     value, with ambiguity regarding whether this refers to its monetary or agricultural
#     value.
# rephrasal:
#   new: "Three siblings - David, Eve, and Frank - have inherited a 90-acre piece of\
#     \ land from their father. The northern 60 acres are suitable for farming but difficult\
#     \ to develop, while the southern 30 acres are unsuitable for farming but ideal\
#     \ for development. Both sections have equal monetary value per acre due to potential\
#     \ real estate development, though the agricultural value differs significantly\
#     \ between the two sections. According to the will, each sibling should receive\
#     \ an equal share of the land\u2019s value, but it is unclear whether this refers\
#     \ to its monetary or agricultural value. How should the 90 acres be divided among\
#     \ the three siblings to ensure that they each get an equal share based on the\
#     \ intended value?"
# terms:
#   doubts: []
#   term_definitions:
#     How should preferences or specific needs of each sibling be considered in the distribution process?: they
#       should not be considered
#     Is it possible that the will intended a mixed approach, combining both monetary and agricultural values?: 'no'
#     What does 'equal share of the land's value' mean in terms of division?: the agricultural
#       value should be the same

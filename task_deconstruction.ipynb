# %% [markdown]
# # Task Deconstruction
#
# The purpose of the task deconstruction graph is to allow users to deconstruct a
# task into its constituent parts, and then execute them in order. This is useful
# for tasks that are too large or complex to be executed all at once, and can be
# serialized. When results have been gathered they will be compiled into a single
# result and returned.
#
# ## Design goals
#
# - **Modular Design**: The code is split into clear components (break_down_task,
#  execute_instruction, compile_final_result), following the Single Responsibility
#  Principle (SRP).
# - **Documentation and typing**: The code is meant to be well documented and
#  typed to facilitate usage.

# %%
from typing import TypedDict, List, Dict, Callable
from typing_extensions import Annotated
from operator import add
from langgraph.graph import StateGraph, START, END
from langgraph.graph.state import CompiledStateGraph
from langchain_core.messages import ChatMessage, AIMessage, HumanMessage
from langchain_core.language_models import BaseChatModel

# %%
class StartState(TypedDict):
    """ the initial input from the user. """
    query: str

class WorkState(TypedDict): 
    """ the intermediate and final states during task execution. """
    query: str
    task_instructions: List[ChatMessage]
    instruction_execution_results: List[str]
    context: List[Dict]
    result: str

# %%
""" break_down_task_graph
This graph starts the task deconstruction process. It takes in the query and
returns a List of task instructions representing subproblems, which are later 
executed by the "execute_instruction" node.
"""

class Instructions(TypedDict):
    """ Collector class for the task instructions. """
    task_instructions: List[str]

def factory_break_down_task(llm: BaseChatModel) \
-> CompiledStateGraph:
    """
    A factory function that creates a function using the provided LLM to break 
    down the user query into smaller tasks.
    """
    def break_down_task(state: StartState) -> WorkState:
        # Use an LLM to break down the user query into a list of instructions
        query = state["query"]
        result = llm.with_structured_output(Instructions).invoke(f"Divide this query into smaller tasks so many can work on it together (they may work in serial or in parellel): {query}")
        print("STEP break down task:", query, result)
        
        instructions = [ ChatMessage(content=task, role="instructor")
                        for task in result["task_instructions"] ]
        
        return {"query": query, "task_instructions": instructions}
    
    graph_builder = StateGraph(input=StartState, output=WorkState)
    graph_builder.add_node("tasker", break_down_task)

    graph_builder.add_edge(START, "tasker")
    graph_builder.add_edge("tasker", END)
    
    return graph_builder.compile()

# %%
""" Solver Graph 
The solver graph is meant to be called iteratively in the "execute_instruction" 
node to solve subproblems from the original query.

If you've not optimized the task breakdown, it might result in repeated 
instructions with the same work, producing frequent calls to the LLM. this could
introduce latency. The code may benefit from memoization or caching mechanisms 
if this execute_instruction processes similar instructions repeatedly.
"""

class Task(TypedDict):
    instructions: List[ChatMessage]
    context: List[Dict]
    result: ChatMessage

def factory_solver(llm: BaseChatModel) -> CompiledStateGraph: 
    """
    A factory function that creates a solver node using the provided LLM to 
    execute a single instruction.
    note: A more production ready version of this graph might make use of 
    context, a system message, etc.
    """
    def execute_instruction(state: Task) -> Task:
        print("STEP execute instruction:", state)
        """ executes an instruction using an LLM and returns its result. """
        messages = [ AIMessage(content=instruction.content) \
                    for instruction in state["instructions"][:-1] 
                 ] + [ HumanMessage(content=state["instructions"][-1].content) ]
        results = llm.invoke(messages)
        
        return { "result": results }

    solver_graph_builder = StateGraph(Task) 
    solver_graph_builder.add_node("execute_instruction", execute_instruction) 

    solver_graph_builder.add_edge(START, "execute_instruction") 
    solver_graph_builder.add_edge("execute_instruction", END)

    return solver_graph_builder.compile()

# %%
""" Task Scheduler
The task scheduler recieves a List of tasks representing subproblems from 
the original query, and executes them in parallel using the provided solver at 
the "execute_instruction" node.

The user is free to substitute in  custom task scheduler if desired. Examples 
uses would be to pre- or post- process the state or tasks before or after the 
tasks are sent.
"""

def factory_scheduler(solver_graph: CompiledStateGraph) \
-> Callable[[WorkState], WorkState]:
    """ Couple an external solver_graph to the scheduler """

    def scheduler(state: WorkState):
        """ 
        The default scheduler recursively calls the sovler_graph with 
        a compiled list of instructions (including the current task 
        instruction), and context.
        """
        context = []
        instructions = []
        for s in state["task_instructions"]:
            instructions.append(s)
            task = {
                "instructions": instructions,
                "context": context
            }
            print("STEP scheduler:", task)
            result = solver_graph.invoke(task)

            context.append(result["result"])

        return {"instruction_execution_results": [solution.content for solution in context]}
    
    return scheduler

# %%
""" Compiler Graph
The compiler graph receives a list of results from the subproblems and combines 
them to produce an answer.
"""

def compile_final_result(state: WorkState):
    # Combine the results from each instruction into a single string.
    print("STEP compiler:", state)

    task_results = "\n".join([ result for result in 
                              state["instruction_execution_results" ]])
    
    return { "result": task_results }

# Default compiler graph
compiler_graph_builder = StateGraph(WorkState)
compiler_graph_builder.add_node("compile_final_result", compile_final_result)
compiler_graph_builder.add_edge(START, "compile_final_result")
compiler_graph_builder.add_edge("compile_final_result", END)
compiler_graph = compiler_graph_builder.compile()

# %%
""" High level functions
These functions ease the construction of task deconstruction graphs.
"""

def deconstruct_task(
    break_down_task: Callable[[StartState], Instructions],
    scheduler: Callable[[WorkState], WorkState],
    compiler_graph=compiler_graph, 
) -> CompiledStateGraph:
  """
  creates a LangGraph that breaks down a task into smaller steps, executes each 
  step in its own subgraph, and compiles the final result.
  """ 
  graph_builder = StateGraph(input=StartState, output=WorkState) 

  graph_builder.add_node("break_down_task", break_down_task) 
  graph_builder.add_node("execute_task", scheduler) 
  graph_builder.add_node("compile_result", compiler_graph) 

  graph_builder.add_edge(START, "break_down_task") 
  graph_builder.add_edge("break_down_task", "execute_task")
  graph_builder.add_edge("execute_task", "compile_result")
  graph_builder.add_edge("compile_result", END)

  return graph_builder.compile()

def factory_deconstruct_task(llm: BaseChatModel) -> CompiledStateGraph:
  """ Factory method to produce a default task deconstructor """
  break_down_task = factory_break_down_task(llm)
  solver_graph = factory_solver(llm)
  scheduler = factory_scheduler(solver_graph)

  return deconstruct_task(break_down_task, scheduler, solver_graph)

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model = "mistral-nemo:12b-instruct-2407-q8_0",
    temperature = 0.2,
    num_ctx=8192,
    num_predict = 4096,
)

graph = factory_deconstruct_task(llm)

for s in graph.stream({"query": "tell me 20 differnt types of animals"}):
    print(s)
# Out:
# STEP break down task: tell me 20 differnt types of animals {'task_instructions': ['Tell me 10 different types of mammals.', 'Tell me 10 different types of birds.']}
# {'break_down_task': {'query': 'tell me 20 differnt types of animals', 'task_instructions': [ChatMessage(content='Tell me 10 different types of mammals.', role='instructor'), ChatMessage(content='Tell me 10 different types of birds.', role='instructor')]}}
# STEP scheduler: {'instructions': [ChatMessage(content='Tell me 10 different types of mammals.', role='instructor')], 'context': []}
# STEP execute instruction: {'instructions': [ChatMessage(content='Tell me 10 different types of mammals.', role='instructor')], 'context': []}
# STEP scheduler: {'instructions': [ChatMessage(content='Tell me 10 different types of mammals.', role='instructor'), ChatMessage(content='Tell me 10 different types of birds.', role='instructor')], 'context': [AIMessage(content='Sure, here are ten different types of mammals from various orders and families:\n\n1. **Primates** (Order Primates):\n   - **Humans** (Homo sapiens): We belong to this order, which includes apes, monkeys, and lemurs.\n   - **Gorillas** (Gorilla): Largest living primates, found in central Africa.\n\n2. **Carnivora** (Order Carnivora):\n   - **Dogs** (Canis lupus familiaris): Domesticated from wolves, they are part of the Canidae family.\n   - **Tigers** (Panthera tigris): The largest big cat species, belonging to the Felidae family.\n\n3. **Artiodactyla** (Order Artiodactyla):\n   - **Elephants** (Loxodonta africana): Largest land mammals, part of the Proboscidea family.\n   - **Giraffes** (Giraffa camelopardalis): Tallest living terrestrial animals, belonging to the Giraffidae family.\n\n4. **Perissodactyla** (Order Perissodactyla):\n   - **Horses** (Equus ferus caballus): Domesticated from wild horses, they belong to the Equidae family.\n   - **Rhinoceros** (Rhinoceros spp.): Five extant species, part of the Rhinocerotidae family.\n\n5. **Marsupials** (Order Marsupialia):\n   - **Kangaroos** (Macropus rufus): Largest marsupials, found in Australia.\n   - **Opossums** (Didelphis spp.): Small mammals with a pouch for their young, native to the Americas.\n\n6. **Cetacea** (Order Cetacea):\n   - **Whales** (Balaenoptera physalus): Marine mammals known for their large size and complex behaviors.\n\n7. **Sirenia** (Order Sirenia):\n   - **Manatees** (Trichechus manatus): Fully aquatic, herbivorous mammals found in shallow, slow-moving waters.\n\n8. **Insectivora** (Order Eulipotyphla):\n   - **Hedgehogs** (Erinaceus europaeus): Small, spiny mammals native to Europe and Africa.\n   - **Moles** (Talpa europaea): Insectivorous mammals with a distinctive burrowing lifestyle.\n\n9. **Rodentia** (Order Rodentia):\n   - **Rats** (Rattus norvegicus): Commonly found in urban areas, they are part of the Muridae family.\n   - **Beavers** (Castor canadensis): Large, semi-aquatic rodents known for their dam-building behavior.\n\n10. **Bats** (Order Chiroptera):\n    - **Fruit bats** (Pteropus spp.): Megabats that feed primarily on fruits.\n    - **Insect-eating bats** (Microchiroptera): Smaller bats that use echolocation to catch insects in flight.', response_metadata={'model': 'mistral-nemo:12b-instruct-2407-q8_0', 'created_at': '2024-09-19T14:11:43.383132Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 26963043917, 'load_duration': 9766583, 'prompt_eval_count': 13, 'prompt_eval_duration': 112549000, 'eval_count': 642, 'eval_duration': 26839859000}, id='run-53e1262f-9138-40e3-8b31-b43165b09c4e-0', usage_metadata={'input_tokens': 13, 'output_tokens': 642, 'total_tokens': 655})]}
# STEP execute instruction: {'instructions': [ChatMessage(content='Tell me 10 different types of mammals.', role='instructor'), ChatMessage(content='Tell me 10 different types of birds.', role='instructor')], 'context': [AIMessage(content='Sure, here are ten different types of mammals from various orders and families:\n\n1. **Primates** (Order Primates):\n   - **Humans** (Homo sapiens): We belong to this order, which includes apes, monkeys, and lemurs.\n   - **Gorillas** (Gorilla): Largest living primates, found in central Africa.\n\n2. **Carnivora** (Order Carnivora):\n   - **Dogs** (Canis lupus familiaris): Domesticated from wolves, they are part of the Canidae family.\n   - **Tigers** (Panthera tigris): The largest big cat species, belonging to the Felidae family.\n\n3. **Artiodactyla** (Order Artiodactyla):\n   - **Elephants** (Loxodonta africana): Largest land mammals, part of the Proboscidea family.\n   - **Giraffes** (Giraffa camelopardalis): Tallest living terrestrial animals, belonging to the Giraffidae family.\n\n4. **Perissodactyla** (Order Perissodactyla):\n   - **Horses** (Equus ferus caballus): Domesticated from wild horses, they belong to the Equidae family.\n   - **Rhinoceros** (Rhinoceros spp.): Five extant species, part of the Rhinocerotidae family.\n\n5. **Marsupials** (Order Marsupialia):\n   - **Kangaroos** (Macropus rufus): Largest marsupials, found in Australia.\n   - **Opossums** (Didelphis spp.): Small mammals with a pouch for their young, native to the Americas.\n\n6. **Cetacea** (Order Cetacea):\n   - **Whales** (Balaenoptera physalus): Marine mammals known for their large size and complex behaviors.\n\n7. **Sirenia** (Order Sirenia):\n   - **Manatees** (Trichechus manatus): Fully aquatic, herbivorous mammals found in shallow, slow-moving waters.\n\n8. **Insectivora** (Order Eulipotyphla):\n   - **Hedgehogs** (Erinaceus europaeus): Small, spiny mammals native to Europe and Africa.\n   - **Moles** (Talpa europaea): Insectivorous mammals with a distinctive burrowing lifestyle.\n\n9. **Rodentia** (Order Rodentia):\n   - **Rats** (Rattus norvegicus): Commonly found in urban areas, they are part of the Muridae family.\n   - **Beavers** (Castor canadensis): Large, semi-aquatic rodents known for their dam-building behavior.\n\n10. **Bats** (Order Chiroptera):\n    - **Fruit bats** (Pteropus spp.): Megabats that feed primarily on fruits.\n    - **Insect-eating bats** (Microchiroptera): Smaller bats that use echolocation to catch insects in flight.', response_metadata={'model': 'mistral-nemo:12b-instruct-2407-q8_0', 'created_at': '2024-09-19T14:11:43.383132Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 26963043917, 'load_duration': 9766583, 'prompt_eval_count': 13, 'prompt_eval_duration': 112549000, 'eval_count': 642, 'eval_duration': 26839859000}, id='run-53e1262f-9138-40e3-8b31-b43165b09c4e-0', usage_metadata={'input_tokens': 13, 'output_tokens': 642, 'total_tokens': 655})]}
# {'execute_task': {'instruction_execution_results': ['Sure, here are ten different types of mammals from various orders and families:\n\n1. **Primates** (Order Primates):\n   - **Humans** (Homo sapiens): We belong to this order, which includes apes, monkeys, and lemurs.\n   - **Gorillas** (Gorilla): Largest living primates, found in central Africa.\n\n2. **Carnivora** (Order Carnivora):\n   - **Dogs** (Canis lupus familiaris): Domesticated from wolves, they are part of the Canidae family.\n   - **Tigers** (Panthera tigris): The largest big cat species, belonging to the Felidae family.\n\n3. **Artiodactyla** (Order Artiodactyla):\n   - **Elephants** (Loxodonta africana): Largest land mammals, part of the Proboscidea family.\n   - **Giraffes** (Giraffa camelopardalis): Tallest living terrestrial animals, belonging to the Giraffidae family.\n\n4. **Perissodactyla** (Order Perissodactyla):\n   - **Horses** (Equus ferus caballus): Domesticated from wild horses, they belong to the Equidae family.\n   - **Rhinoceros** (Rhinoceros spp.): Five extant species, part of the Rhinocerotidae family.\n\n5. **Marsupials** (Order Marsupialia):\n   - **Kangaroos** (Macropus rufus): Largest marsupials, found in Australia.\n   - **Opossums** (Didelphis spp.): Small mammals with a pouch for their young, native to the Americas.\n\n6. **Cetacea** (Order Cetacea):\n   - **Whales** (Balaenoptera physalus): Marine mammals known for their large size and complex behaviors.\n\n7. **Sirenia** (Order Sirenia):\n   - **Manatees** (Trichechus manatus): Fully aquatic, herbivorous mammals found in shallow, slow-moving waters.\n\n8. **Insectivora** (Order Eulipotyphla):\n   - **Hedgehogs** (Erinaceus europaeus): Small, spiny mammals native to Europe and Africa.\n   - **Moles** (Talpa europaea): Insectivorous mammals with a distinctive burrowing lifestyle.\n\n9. **Rodentia** (Order Rodentia):\n   - **Rats** (Rattus norvegicus): Commonly found in urban areas, they are part of the Muridae family.\n   - **Beavers** (Castor canadensis): Large, semi-aquatic rodents known for their dam-building behavior.\n\n10. **Bats** (Order Chiroptera):\n    - **Fruit bats** (Pteropus spp.): Megabats that feed primarily on fruits.\n    - **Insect-eating bats** (Microchiroptera): Smaller bats that use echolocation to catch insects in flight.', 'Sure, here are ten different types of birds from various families and habitats:\n\n1. **American Robin** (Turdus migratorius): Known for its bright orange breast and preference for foraging on lawns.\n\n2. **Great Blue Heron** (Ardea herodias): A large wading bird with a blue-gray body, found near bodies of water in North America.\n\n3. **Bald Eagle** (Haliaeetus leucocephalus): The national bird of the United States, known for its white head and tail contrasting with a dark brown body.\n\n4. **Puffin** (Fratercula arctica): A seabird with a colorful beak and orange legs, found in the North Atlantic Ocean.\n\n5. **Honey Bee** (Apis mellifera): While not typically thought of as a bird, honey bees are indeed flying insects that play a crucial role in pollination.\n\n6. **Ostrich** (Struthio camelus): The largest species of bird, native to Africa and known for its flightless nature and powerful legs.\n\n7. **Peregrine Falcon** (Falco peregrinus): A bird of prey found on every continent except Antarctica, known for its speed and agility in flight.\n\n8. **Emu** (Dromaius novaehollandiae): The second-largest species of bird by height, native to Australia and also flightless.\n\n9. **Keel-billed Toucan** (Ramphastos sulfuratus): A colorful tropical bird known for its large, vibrant beak.\n\n10. **Common Loon** (Gavia immer): A freshwater diving bird found in North America, known for its haunting calls and distinctive appearance on water.']}}
# ---------------------------------------------------------------------------
# InvalidUpdateError                        Traceback (most recent call last)
# Cell In[40], line 12
#       3 llm = ChatOllama(
#       4     model = "mistral-nemo:12b-instruct-2407-q8_0",
#       5     temperature = 0.2,
#       6     num_ctx=8192,
#       7     num_predict = 4096,
#       8 )
#      10 graph = factory_deconstruct_task(llm)
# ---> 12 for s in graph.stream({"query": "tell me 20 differnt types of animals"}):
#      13     print(s)
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1221, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1210 # Similarly to Bulk Synchronous Parallel / Pregel model
#    1211 # computation proceeds in steps, while there are channel updates
#    1212 # channel updates from step N are only visible in step N+1
#    1213 # channels are guaranteed to be immutable for the duration of the step,
#    1214 # with channel updates applied only at the transition between steps
#    1215 while loop.tick(
#    1216     input_keys=self.input_channels,
#    1217     interrupt_before=interrupt_before,
#    1218     interrupt_after=interrupt_after,
#    1219     manager=run_manager,
#    1220 ):
# -> 1221     for _ in runner.tick(
#    1222         loop.tasks.values(),
#    1223         timeout=self.step_timeout,
#    1224         retry_policy=self.retry_policy,
#    1225     ):
#    1226         # emit output
#    1227         for o in output():
#    1228             yield o
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:87, in PregelRunner.tick(self, tasks, timeout, retry_policy)
#      85     yield
#      86 # panic on failure or timeout
# ---> 87 _panic_or_proceed(all_futures)
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:190, in _panic_or_proceed(futs, timeout_exc_cls)
#     188             inflight.pop().cancel()
#     189         # raise the exception
# --> 190         raise exc
#     191 if inflight:
#     192     # if we got here means we timed out
#     193     while inflight:
#     194         # cancel all pending tasks
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/executor.py:59, in BackgroundExecutor.done(self, task)
#      57 def done(self, task: concurrent.futures.Future) -> None:
#      58     try:
# ---> 59         task.result()
#      60     except GraphInterrupt:
#      61         # This exception is an interruption signal, not an error
#      62         # so we don't want to re-raise it on exit
#      63         self.tasks.pop(task)
#
# File ~/.pyenv/versions/3.12.0/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.12.0/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.pyenv/versions/3.12.0/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/retry.py:26, in run_with_retry(task, retry_policy)
#      24 task.writes.clear()
#      25 # run the task
# ---> 26 task.proc.invoke(task.input, task.config)
#      27 # if successful, end
#      28 break
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:341, in RunnableSeq.invoke(self, input, config, **kwargs)
#     339 context.run(_set_config_context, config)
#     340 if i == 0:
# --> 341     input = context.run(step.invoke, input, config, **kwargs)
#     342 else:
#     343     input = context.run(step.invoke, input, config)
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1468, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    1466 else:
#    1467     chunks = []
# -> 1468 for chunk in self.stream(
#    1469     input,
#    1470     config,
#    1471     stream_mode=stream_mode,
#    1472     output_keys=output_keys,
#    1473     interrupt_before=interrupt_before,
#    1474     interrupt_after=interrupt_after,
#    1475     debug=debug,
#    1476     **kwargs,
#    1477 ):
#    1478     if stream_mode == "values":
#    1479         latest = chunk
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1221, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1210 # Similarly to Bulk Synchronous Parallel / Pregel model
#    1211 # computation proceeds in steps, while there are channel updates
#    1212 # channel updates from step N are only visible in step N+1
#    1213 # channels are guaranteed to be immutable for the duration of the step,
#    1214 # with channel updates applied only at the transition between steps
#    1215 while loop.tick(
#    1216     input_keys=self.input_channels,
#    1217     interrupt_before=interrupt_before,
#    1218     interrupt_after=interrupt_after,
#    1219     manager=run_manager,
#    1220 ):
# -> 1221     for _ in runner.tick(
#    1222         loop.tasks.values(),
#    1223         timeout=self.step_timeout,
#    1224         retry_policy=self.retry_policy,
#    1225     ):
#    1226         # emit output
#    1227         for o in output():
#    1228             yield o
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:87, in PregelRunner.tick(self, tasks, timeout, retry_policy)
#      85     yield
#      86 # panic on failure or timeout
# ---> 87 _panic_or_proceed(all_futures)
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:190, in _panic_or_proceed(futs, timeout_exc_cls)
#     188             inflight.pop().cancel()
#     189         # raise the exception
# --> 190         raise exc
#     191 if inflight:
#     192     # if we got here means we timed out
#     193     while inflight:
#     194         # cancel all pending tasks
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/executor.py:59, in BackgroundExecutor.done(self, task)
#      57 def done(self, task: concurrent.futures.Future) -> None:
#      58     try:
# ---> 59         task.result()
#      60     except GraphInterrupt:
#      61         # This exception is an interruption signal, not an error
#      62         # so we don't want to re-raise it on exit
#      63         self.tasks.pop(task)
#
# File ~/.pyenv/versions/3.12.0/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.12.0/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.pyenv/versions/3.12.0/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/retry.py:26, in run_with_retry(task, retry_policy)
#      24 task.writes.clear()
#      25 # run the task
# ---> 26 task.proc.invoke(task.input, task.config)
#      27 # if successful, end
#      28 break
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:121, in RunnableCallable.invoke(self, input, config, **kwargs)
#     119     context = copy_context()
#     120     context.run(_set_config_context, child_config)
# --> 121     ret = context.run(self.func, input, **kwargs)
#     122 except BaseException as e:
#     123     run_manager.on_chain_error(e)
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/write.py:86, in ChannelWrite._write(self, input, config)
#      79 def _write(self, input: Any, config: RunnableConfig) -> None:
#      80     writes = [
#      81         ChannelWriteEntry(write.channel, input, write.skip_none, write.mapper)
#      82         if isinstance(write, ChannelWriteEntry) and write.value is PASSTHROUGH
#      83         else write
#      84         for write in self.writes
#      85     ]
# ---> 86     self.do_write(
#      87         config,
#      88         writes,
#      89         self.require_at_least_one_of if input is not None else None,
#      90     )
#      91     return input
#
# File /Users/Shared/Public/langchain/Introduction to LangGraph/langchain-academy/venv/lib/python3.12/site-packages/langgraph/pregel/write.py:139, in ChannelWrite.do_write(config, writes, require_at_least_one_of)
#     137 if require_at_least_one_of is not None:
#     138     if not {chan for chan, _ in filtered} & set(require_at_least_one_of):
# --> 139         raise InvalidUpdateError(
#     140             f"Must write to at least one of {require_at_least_one_of}"
#     141         )
#     142 write: TYPE_SEND = config["configurable"][CONFIG_KEY_SEND]
#     143 write(sends + filtered)
#
# InvalidUpdateError: Must write to at least one of ['instructions', 'context', 'result']

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    #model = "mistral-small:22b-instruct-2409-q6_K",
    model = "qwen2.5:32b-instruct-q6_K",
    temperature = 0.2,
    num_ctx=32768,
    num_predict = 5120,
)

# %%
from typing import Annotated, Sequence, TypedDict
from langgraph.graph import StateGraph
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.messages.tool import ToolMessage
from langchain_core.prompts import ChatPromptTemplate
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt import ToolNode, tools_condition
from IPython.display import Image, display
#from langchain_core.runnables import RunnableConfig

# Define the Collatz function
def collatz(n: int) -> int:
    """Apply the collatz operation to a number"""
    return 3 * n + 1 if n % 2 else n // 2

# Create the LLM and bind the tool
llm = llm.bind_tools([collatz])

# Define the state
class State(TypedDict):
    messages: Annotated[Sequence[HumanMessage | AIMessage], "The messages in the conversation"]
    collatz_sequence: Sequence[int]

def format_sequence(s: Sequence[int]) -> str:
    return "->".join(str(x) for x in s)

# Create the prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are calculating the Collatz sequence for numbers. Use the collatz tool to generate the next number in the sequence from the last number in the sequence. Collatz sequences end in a loop like \"4->2->1\".\nTips\nThis requires patience and a meticulous approach. Be sure to follow a serial process: wait for each call to the tool to complete before making another call. DO NOT make repeat calls to the tool. You must STOP calling the tool when you reach 4, 2, or 1, and respond with the complete sequence you have generated."),
    ("human", "Generate the collatz sequence. STOP when the last number in the sequence is 4, 2, or 1. The current sequence is: {sequence}. When you are finished, tell me the completed sequence.")
])

# Define the agent function
def agent(state: State) -> State:
    messages = state.get("messages", [])
    values = state.get("collatz_sequence", [])
    if messages and isinstance(messages[-1], ToolMessage):
        values.append(int(state["messages"][-1].content))

    msg = llm.invoke(prompt.format_messages(sequence=format_sequence(values)))

    # Generate the next number in the sequence
    return {"messages": [msg]}

# Create the graph
workflow = StateGraph(State)
workflow.add_node("agent", agent)
workflow.add_node("tools", ToolNode([collatz]))

workflow.add_conditional_edges(
    "agent",
    # If the latest message (result) from agent is a tool call -> tools_condition routes to tools
    # If the latest message (result) from agent is a not a tool call -> tools_condition routes to END
    tools_condition
)
workflow.add_edge("tools", "agent")

workflow.set_entry_point("agent")


# Compile the graph
memory = MemorySaver()

app = workflow.compile(checkpointer=memory)
display(Image(app.get_graph(xray=True).draw_mermaid_png()))

# Run the graph
inputs = {"messages": [], "collatz_sequence": [9]}

config = {"configurable": {"thread_id": "1"}, "recursion_limit": 1024}
#o = app.invoke(inputs)
#print(o["collatz_sequence"])
for upd in app.stream(inputs, config, stream_mode="updates"):
    print(upd)

print(format_sequence(app.get_state(config).values["collatz_sequence"]))
print("Sequence complete. Reached the 4->2->1 loop.")
# Out:
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:53:51.988687Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 9}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 5020754209, 'load_duration': 31684542, 'prompt_eval_count': 299, 'prompt_eval_duration': 3111656000, 'eval_count': 20, 'eval_duration': 1871999000}, id='run-1abb20b6-d7e6-4dde-b72c-ff23ed43a2ff-0', tool_calls=[{'name': 'collatz', 'args': {'n': 9}, 'id': 'f2999643-2d1f-4f5b-a9e7-4327bc0e0876', 'type': 'tool_call'}], usage_metadata={'input_tokens': 299, 'output_tokens': 20, 'total_tokens': 319})]}}
# {'tools': {'messages': [ToolMessage(content='28', name='collatz', tool_call_id='f2999643-2d1f-4f5b-a9e7-4327bc0e0876')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:53:54.240248Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 28}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2232346000, 'load_duration': 13155625, 'prompt_eval_count': 302, 'prompt_eval_duration': 334886000, 'eval_count': 21, 'eval_duration': 1878792000}, id='run-cd05b115-e54f-419e-abc7-f424284f5419-0', tool_calls=[{'name': 'collatz', 'args': {'n': 28}, 'id': 'cc35b2dc-8a67-4942-9779-447849593a7a', 'type': 'tool_call'}], usage_metadata={'input_tokens': 302, 'output_tokens': 21, 'total_tokens': 323})]}}
# {'tools': {'messages': [ToolMessage(content='14', name='collatz', tool_call_id='cc35b2dc-8a67-4942-9779-447849593a7a')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:53:56.472248Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 14}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2221577875, 'load_duration': 10345333, 'prompt_eval_count': 305, 'prompt_eval_duration': 338273000, 'eval_count': 21, 'eval_duration': 1870189000}, id='run-914e7580-8609-4d15-9ae3-3360ef64bbf1-0', tool_calls=[{'name': 'collatz', 'args': {'n': 14}, 'id': 'b4804b72-8f51-4c8d-8a31-6786128e1273', 'type': 'tool_call'}], usage_metadata={'input_tokens': 305, 'output_tokens': 21, 'total_tokens': 326})]}}
# {'tools': {'messages': [ToolMessage(content='7', name='collatz', tool_call_id='b4804b72-8f51-4c8d-8a31-6786128e1273')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:53:58.586398Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 7}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2104919083, 'load_duration': 9918958, 'prompt_eval_count': 307, 'prompt_eval_duration': 337415000, 'eval_count': 20, 'eval_duration': 1755078000}, id='run-da59103e-e880-4df1-aaca-b3aeec72355c-0', tool_calls=[{'name': 'collatz', 'args': {'n': 7}, 'id': '5bbc1e61-1dbc-420c-844f-f9037b3e0f7c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 307, 'output_tokens': 20, 'total_tokens': 327})]}}
# {'tools': {'messages': [ToolMessage(content='22', name='collatz', tool_call_id='5bbc1e61-1dbc-420c-844f-f9037b3e0f7c')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:00.780415Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 22}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2185236417, 'load_duration': 10391334, 'prompt_eval_count': 310, 'prompt_eval_duration': 336480000, 'eval_count': 21, 'eval_duration': 1835937000}, id='run-25a49607-7343-4547-9042-6b874824d0b9-0', tool_calls=[{'name': 'collatz', 'args': {'n': 22}, 'id': '42fb26e6-31db-46ce-9f91-04981526867d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 310, 'output_tokens': 21, 'total_tokens': 331})]}}
# {'tools': {'messages': [ToolMessage(content='11', name='collatz', tool_call_id='42fb26e6-31db-46ce-9f91-04981526867d')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:02.988133Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 11}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2204888042, 'load_duration': 10448917, 'prompt_eval_count': 313, 'prompt_eval_duration': 337885000, 'eval_count': 21, 'eval_duration': 1853923000}, id='run-4ec450dc-32de-464d-a98b-d5f9893ac20b-0', tool_calls=[{'name': 'collatz', 'args': {'n': 11}, 'id': '4f571034-6e06-4bac-8bdf-a587a514de46', 'type': 'tool_call'}], usage_metadata={'input_tokens': 313, 'output_tokens': 21, 'total_tokens': 334})]}}
# {'tools': {'messages': [ToolMessage(content='34', name='collatz', tool_call_id='4f571034-6e06-4bac-8bdf-a587a514de46')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:05.147729Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 34}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2151978500, 'load_duration': 10338458, 'prompt_eval_count': 316, 'prompt_eval_duration': 336020000, 'eval_count': 21, 'eval_duration': 1803098000}, id='run-c412088f-113c-40d1-be66-e24e35aebb92-0', tool_calls=[{'name': 'collatz', 'args': {'n': 34}, 'id': '49b27263-e3c2-42cc-b670-e858ee3dfe6e', 'type': 'tool_call'}], usage_metadata={'input_tokens': 316, 'output_tokens': 21, 'total_tokens': 337})]}}
# {'tools': {'messages': [ToolMessage(content='17', name='collatz', tool_call_id='49b27263-e3c2-42cc-b670-e858ee3dfe6e')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:07.333721Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 17}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2182500208, 'load_duration': 10193833, 'prompt_eval_count': 319, 'prompt_eval_duration': 336542000, 'eval_count': 21, 'eval_duration': 1833273000}, id='run-78df5143-a99f-48ad-ba78-55c97043b60c-0', tool_calls=[{'name': 'collatz', 'args': {'n': 17}, 'id': '8691b3ce-7416-4a5c-98f9-1992cddaa782', 'type': 'tool_call'}], usage_metadata={'input_tokens': 319, 'output_tokens': 21, 'total_tokens': 340})]}}
# {'tools': {'messages': [ToolMessage(content='52', name='collatz', tool_call_id='8691b3ce-7416-4a5c-98f9-1992cddaa782')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:09.465789Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 52}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2123640834, 'load_duration': 10058667, 'prompt_eval_count': 322, 'prompt_eval_duration': 337116000, 'eval_count': 21, 'eval_duration': 1773862000}, id='run-1247a426-661c-49c2-9498-305c2d7a6dbb-0', tool_calls=[{'name': 'collatz', 'args': {'n': 52}, 'id': '8cd99e0d-ceb5-4c24-8ab0-cb51e279368e', 'type': 'tool_call'}], usage_metadata={'input_tokens': 322, 'output_tokens': 21, 'total_tokens': 343})]}}
# {'tools': {'messages': [ToolMessage(content='26', name='collatz', tool_call_id='8cd99e0d-ceb5-4c24-8ab0-cb51e279368e')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:11.607595Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 26}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2132160666, 'load_duration': 10198375, 'prompt_eval_count': 325, 'prompt_eval_duration': 333610000, 'eval_count': 21, 'eval_duration': 1785681000}, id='run-f1dc3cba-e34c-44a0-ab02-b74ab0f12f4c-0', tool_calls=[{'name': 'collatz', 'args': {'n': 26}, 'id': '54f1a0c4-5452-486d-a914-7168edf6e3e2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 325, 'output_tokens': 21, 'total_tokens': 346})]}}
# {'tools': {'messages': [ToolMessage(content='13', name='collatz', tool_call_id='54f1a0c4-5452-486d-a914-7168edf6e3e2')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:13.751948Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 13}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2135470792, 'load_duration': 9902500, 'prompt_eval_count': 328, 'prompt_eval_duration': 336911000, 'eval_count': 21, 'eval_duration': 1786031000}, id='run-16a8b6ac-9d28-4ff3-a2e8-fa1777167a37-0', tool_calls=[{'name': 'collatz', 'args': {'n': 13}, 'id': 'dc38b037-50ff-4cd2-9669-f515b27402e6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 328, 'output_tokens': 21, 'total_tokens': 349})]}}
# {'tools': {'messages': [ToolMessage(content='40', name='collatz', tool_call_id='dc38b037-50ff-4cd2-9669-f515b27402e6')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:15.874529Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 40}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2118193958, 'load_duration': 10888375, 'prompt_eval_count': 331, 'prompt_eval_duration': 336283000, 'eval_count': 21, 'eval_duration': 1768661000}, id='run-2d7b6cb3-a18a-4e51-92a5-db50055410ea-0', tool_calls=[{'name': 'collatz', 'args': {'n': 40}, 'id': '67066036-71b4-42aa-9c2f-7651a5f1e209', 'type': 'tool_call'}], usage_metadata={'input_tokens': 331, 'output_tokens': 21, 'total_tokens': 352})]}}
# {'tools': {'messages': [ToolMessage(content='20', name='collatz', tool_call_id='67066036-71b4-42aa-9c2f-7651a5f1e209')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:17.992669Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 20}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2109905584, 'load_duration': 10979500, 'prompt_eval_count': 334, 'prompt_eval_duration': 336625000, 'eval_count': 21, 'eval_duration': 1759739000}, id='run-331219c6-6e94-413b-bf6d-b52008ed32f9-0', tool_calls=[{'name': 'collatz', 'args': {'n': 20}, 'id': '7ed4ffef-0aa9-46eb-9335-b2fdc3f134ed', 'type': 'tool_call'}], usage_metadata={'input_tokens': 334, 'output_tokens': 21, 'total_tokens': 355})]}}
# {'tools': {'messages': [ToolMessage(content='10', name='collatz', tool_call_id='7ed4ffef-0aa9-46eb-9335-b2fdc3f134ed')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:20.140657Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 10}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2138951666, 'load_duration': 10020125, 'prompt_eval_count': 337, 'prompt_eval_duration': 336601000, 'eval_count': 21, 'eval_duration': 1789725000}, id='run-a4d8c304-3473-4e64-a46c-41c3104f67fe-0', tool_calls=[{'name': 'collatz', 'args': {'n': 10}, 'id': '79e2866a-70ae-4579-b8bd-12a2494cd66c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 337, 'output_tokens': 21, 'total_tokens': 358})]}}
# {'tools': {'messages': [ToolMessage(content='5', name='collatz', tool_call_id='79e2866a-70ae-4579-b8bd-12a2494cd66c')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:22.16566Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 5}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2015744708, 'load_duration': 10339708, 'prompt_eval_count': 339, 'prompt_eval_duration': 335869000, 'eval_count': 20, 'eval_duration': 1666796000}, id='run-16fe5d2f-0f23-4925-a8b0-456f5f261fff-0', tool_calls=[{'name': 'collatz', 'args': {'n': 5}, 'id': '82009940-1345-49e9-ab6f-d9095116fbb6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 339, 'output_tokens': 20, 'total_tokens': 359})]}}
# {'tools': {'messages': [ToolMessage(content='16', name='collatz', tool_call_id='82009940-1345-49e9-ab6f-d9095116fbb6')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:24.282588Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 16}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2107603333, 'load_duration': 10155125, 'prompt_eval_count': 342, 'prompt_eval_duration': 337446000, 'eval_count': 21, 'eval_duration': 1757388000}, id='run-8ae8778c-fa0d-471b-931b-ce3a8a97486c-0', tool_calls=[{'name': 'collatz', 'args': {'n': 16}, 'id': '91d2ac98-4280-4a81-8184-fdf09d370d07', 'type': 'tool_call'}], usage_metadata={'input_tokens': 342, 'output_tokens': 21, 'total_tokens': 363})]}}
# {'tools': {'messages': [ToolMessage(content='8', name='collatz', tool_call_id='91d2ac98-4280-4a81-8184-fdf09d370d07')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:26.306875Z', 'message': {'role': 'assistant', 'content': '', 'tool_calls': [{'function': {'name': 'collatz', 'arguments': {'n': 8}}}]}, 'done_reason': 'stop', 'done': True, 'total_duration': 2019915792, 'load_duration': 10411625, 'prompt_eval_count': 344, 'prompt_eval_duration': 337247000, 'eval_count': 20, 'eval_duration': 1669624000}, id='run-513e57fc-88d4-44f7-98ef-fa7064f029cd-0', tool_calls=[{'name': 'collatz', 'args': {'n': 8}, 'id': '867ed8bc-f21c-4ce2-8958-14495cc95d48', 'type': 'tool_call'}], usage_metadata={'input_tokens': 344, 'output_tokens': 20, 'total_tokens': 364})]}}
# {'tools': {'messages': [ToolMessage(content='4', name='collatz', tool_call_id='867ed8bc-f21c-4ce2-8958-14495cc95d48')]}}
# {'agent': {'messages': [AIMessage(content='The given Collatz sequence ends with 4, which means we should stop here as per the instructions. Therefore, no further calls to the collatz tool are needed.\n\nThe complete Collatz sequence starting from 9 is: 9->28->14->7->22->11->34->17->52->26->13->40->20->10->5->16->8->4.', additional_kwargs={}, response_metadata={'model': 'qwen2.5:32b-instruct-q6_K', 'created_at': '2024-09-23T14:54:35.454416Z', 'message': {'role': 'assistant', 'content': 'The given Collatz sequence ends with 4, which means we should stop here as per the instructions. Therefore, no further calls to the collatz tool are needed.\n\nThe complete Collatz sequence starting from 9 is: 9->28->14->7->22->11->34->17->52->26->13->40->20->10->5->16->8->4.'}, 'done_reason': 'stop', 'done': True, 'total_duration': 9137550292, 'load_duration': 10222834, 'prompt_eval_count': 346, 'prompt_eval_duration': 336729000, 'eval_count': 96, 'eval_duration': 8787442000}, id='run-43d0ebda-3393-4701-b75f-f3664f30038d-0', usage_metadata={'input_tokens': 346, 'output_tokens': 96, 'total_tokens': 442})]}}
# 9->28->14->7->22->11->34->17->52->26->13->40->20->10->5->16->8->4
# Sequence complete. Reached the 4->2->1 loop.
